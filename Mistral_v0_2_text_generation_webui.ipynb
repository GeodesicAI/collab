# %% [markdown]
# <a href="https://colab.research.google.com/github/GeodesicAI/collab/blob/main/Mistral_v0_2_text_generation_webui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !apt-get -y install -qq aria2

# !git clone -b v3.0 https://github.com/camenduru/text-generation-webui
# %cd /content/text-generation-webui
# !pip install -q -r requirements.txt
# !pip uninstall flash-attn -y
# !pip install -q flash-attn==2.3.1.post1 --no-build-isolation -U

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/config.json -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/generation_config.json -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o generation_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/model-00001-of-00003.safetensors -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o model-00001-of-00003.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/model-00002-of-00003.safetensors -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o model-00002-of-00003.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/model-00003-of-00003.safetensors -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o model-00003-of-00003.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/model.safetensors.index.json -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o model.safetensors.index.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/pytorch_model-00001-of-00003.bin -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o pytorch_model-00001-of-00003.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/pytorch_model-00002-of-00003.bin -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o pytorch_model-00002-of-00003.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/pytorch_model-00003-of-00003.bin -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o pytorch_model-00003-of-00003.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/pytorch_model.bin.index.json -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o pytorch_model.bin.index.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/special_tokens_map.json -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/tokenizer.json -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o tokenizer.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/tokenizer.model -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o tokenizer.model
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2/resolve/main/tokenizer_config.json -d /content/text-generation-webui/models/Mistral-7B-v0.2 -o tokenizer_config.json

# !echo "dark_theme: true" > /content/settings.yaml
# !echo "chat_style: wpp" >> /content/settings.yaml
# !echo "mode: 'instruct'" >> /content/settings.yaml
# !echo "instruction_template: 'Mistral'" >> /content/settings.yaml

# %cd /content/text-generation-webui
# !python server.py --load-in-8bit --share --settings /content/settings.yaml --model /content/text-generation-webui/models/Mistral-7B-v0.2
# Out:
# /content
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 121753 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Cloning into 'text-generation-webui'...
# remote: Enumerating objects: 17379, done.
# remote: Counting objects: 100% (547/547), done.
# remote: Compressing objects: 100% (276/276), done.
# remote: Total 17379 (delta 382), reused 377 (delta 271), pack-reused 16832
# Receiving objects: 100% (17379/17379), 26.51 MiB | 22.95 MiB/s, done.
# Resolving deltas: 100% (12212/12212), done.
# /content/text-generation-webui
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 MB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 MB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 57.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 MB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.6/120.6 MB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.5/739.5 kB 46.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 85.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 47.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 76.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 99.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 80.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.1/407.1 kB 42.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 24.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 103.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 101.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 92.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 30.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 35.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 95.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 33.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 31.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 116.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 18.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 92.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 MB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.4/33.4 MB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 27.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 33.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 98.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 94.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 12.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 49.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 60.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 78.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 50.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 79.1 MB/s eta 0:00:00
#   Building wheel for hqq (setup.py) ... done
#   Building wheel for rouge-score (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for sqlitedict (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# Found existing installation: flash-attn 2.5.6
# Uninstalling flash-attn-2.5.6:
#   Successfully uninstalled flash-attn-2.5.6
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5bdf1b|OK  |    72KiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 433461|OK  |    18KiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/generation_config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c146a9|OK  |   198MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/model-00001-of-00003.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d2f57c|OK  |   209MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/model-00002-of-00003.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 74d08b|OK  |   203MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/model-00003-of-00003.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# eeff00|OK  |   3.9MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/model.safetensors.index.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 41265d|OK  |   232MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/pytorch_model-00001-of-00003.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# fdf243|OK  |   225MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/pytorch_model-00002-of-00003.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 569297|OK  |   236MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/pytorch_model-00003-of-00003.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8e6aed|OK  |   2.8MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/pytorch_model.bin.index.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d99a53|OK  |    10KiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/special_tokens_map.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e5135a|OK  |   5.5MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/tokenizer.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f58f15|OK  |    13MiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/tokenizer.model
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6a7e08|OK  |   178KiB/s|/content/text-generation-webui/models/Mistral-7B-v0.2/tokenizer_config.json
#
# Status Legend:
# (OK):download completed.
# /content/text-generation-webui
# 09:09:52-120965 INFO     Starting Text generation web UI
# 09:09:52-125191 INFO     Loading settings from "/content/settings.yaml"
# 09:09:52-140544 INFO     Loading "Mistral-7B-v0.2"
# Loading checkpoint shards: 100% 3/3 [01:04<00:00, 21.57s/it]
# 09:11:01-373445 INFO     LOADER: "Transformers"
# 09:11:01-374759 INFO     TRUNCATION LENGTH: 32768
# 09:11:01-375815 INFO     INSTRUCTION TEMPLATE: "Custom (obtained from model metadata)"
# 09:11:01-376857 INFO     Loaded the model in 69.23 seconds.
# 09:11:01-377842 INFO     Loading the extension "gallery"
#
# Running on local URL:  http://127.0.0.1:7860
#
# Running on public URL: https://df5816d9dc9911f13c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# 2024-03-26 09:13:17.286164: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-26 09:13:17.286288: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-26 09:13:17.412705: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-26 09:13:19.794484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Output generated in 132.63 seconds (2.96 tokens/s, 393 tokens, context 17, seed 1398374018)
